# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../audios/audio_clips.csv")

# %%
df.head()
# Out:
#           0       0.1       0.2
# 0 -0.000003 -0.087522 -0.001348
# 1 -0.000015 -0.088529  0.007804
# 2 -0.000016 -0.089045  0.028473
# 3 -0.000015 -0.089760  0.053316
# 4 -0.000015 -0.086871  0.075997

# %%
Audio(df['0'].values, rate=32000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
